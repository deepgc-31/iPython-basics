# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/Bishwadeep GC/Desktop/INeuron/Code/Pandas/ex1.csv")     #using backlash as it is in different directory
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
type(df)                #2 col & n rows(dataframe-tabular)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
#df.tail()
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
a=pd.read_table(r'C:\Users\Bishwadeep GC\Desktop\INeuron\Code\Pandas\test.tsv')        #using 'r' to handle unique codes
a
# Out:
#         test   test test.1 test.2 test.3
# sudh    sudh   sudh   sudh   sudh   sudh
# kumar  kumar  kumar  kumar  kumar  kumar

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
df=pd.read_csv(r'C:\Users\Bishwadeep GC\Desktop\INeuron\Code\Pandas\test.tsv',sep='\t')         #using csv to read tsv
df
# Out:
#         test   test test.1 test.2 test.3
# sudh    sudh   sudh   sudh   sudh   sudh
# kumar  kumar  kumar  kumar  kumar  kumar

# %%
df1=pd.read_csv('C:/Users/Bishwadeep GC/Desktop/INeuron/Code/Pandas/ex1.csv',header=None)  #considering first row as not headers
df1
# Out:
#    0   1   2   3        4
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12      foo

# %%
df2=pd.read_csv('C:/Users/Bishwadeep GC/Desktop/INeuron/Code/Pandas/ex1.csv',names=['gd','ed','fd','md','rd','sd'])  #cant contain same name, headers name(column name)
df2
# Out:
#   gd  ed  fd  md       rd  sd
# 0  a   b   c   d  message NaN
# 1  1   2   3   4    hello NaN
# 2  5   6   7   8    world NaN
# 3  9  10  11  12      foo NaN

# %%
df3=pd.read_table(r"C:\Users\Bishwadeep GC\Desktop\INeuron\Code\Pandas\csv_mindex.csv",sep=",",index_col=["key1","key2"])     #row name
df3
# Out:
#            value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      d          7       8
# two  a          9      10
#      b         11      12
#      c         13      14
#      d         15      16

# %%
df4=pd.read_csv(r"C:\Users\Bishwadeep GC\Desktop\INeuron\Code\Pandas\ex4.csv",skiprows=[0,2,3])   #removing junk rows
df4
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
df5=pd.read_csv(r"C:\Users\Bishwadeep GC\Desktop\INeuron\Code\Pandas\ex5.csv")     #NaN - null or missing value
print(df5)
pd.isnull(df5)
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo
#    something      a      b      c      d  message
# 0      False  False  False  False  False     True
# 1      False  False  False   True  False    False
# 2      False  False  False  False  False    False

# %%
df6=pd.read_csv(r"C:\Users\Bishwadeep GC\Desktop\INeuron\Code\Pandas\ex5.csv",na_values=[3])   # replacing 3 with NaN value
df6
# Out:
#   something  a   b     c   d message
# 0       one  1   2   NaN   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
df7=pd.read_excel(r"C:\Users\Bishwadeep GC\Desktop\Data science\Practise excel files\cars.xls",sheet_name='Sheet1')
df7.head(7)
# Out:
#     MPG  CYL    ENG   WGT
# 0  18.0    8  307.0  3504
# 1  15.0    8  350.0  3693
# 2  18.0    8  318.0  3436
# 3  16.0    8  304.0  3433
# 4  17.0    8  302.0  3449
# 5  15.0    8  429.0  4341
# 6  14.0    8  454.0  4354

# %%
url="https://www.basketball-reference.com/leagues/NBA_2015.html#misc_stats::none"
df8=pd.read_html(url)
print(type(df8))
df8[0]
# Out:
# <class 'list'>
#       Eastern Conference                   W                   L  \
# 0      Atlantic Division   Atlantic Division   Atlantic Division
# 1       Toronto Raptors*                  49                  33
# 2        Boston Celtics*                  40                  42
# 3         Brooklyn Nets*                  38                  44
# 4     Philadelphia 76ers                  18                  64
# 5        New York Knicks                  17                  65
# 6       Central Division    Central Division    Central Division
# 7   Cleveland Cavaliers*                  53                  29
# 8         Chicago Bulls*                  50                  32
# 9       Milwaukee Bucks*                  41                  41
# 10        Indiana Pacers                  38                  44
# 11       Detroit Pistons                  32                  50
# 12    Southeast Division  Southeast Division  Southeast Division
# ...
